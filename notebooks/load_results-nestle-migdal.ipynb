# %% [markdown]
# # Loading results

# %%
# %run common_init.py
# Out:
# Start import
# Host: stbc-i2.nikhef.nl
# calculating effective efficiency for Xe detector done
# calculating effective efficiency for Ge detector done
# calculating effective efficiency for Ar detector done
# calculating effective efficiency for Xe_migd detector done
# calculating effective efficiency for Ge_migd detector done
# calculating effective efficiency for Ar_migd detector done
# Done import
# SYSTEM
# 	Running on linux
# 	Python version 3.7.4 (default, Aug 13 2019, 20:35:49) [GCC 7.3.0]
# 	Python installation /data/xenon/joranang/anaconda/envs/dddm/bin/python
# MODULES
# 	DirectDmTargets
# 		ver.:	0.2.0
# 		Path:	/data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/
#
# 	wimprates
# 		ver.:	0.3.2
# 		Path:	/data/xenon/joranang/software/wimprates/wimprates/

# %%
import multihist as mh

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from itertools import cycle
import scipy.optimize

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', 150)

# %%
# loading normal results.
results = {}
for i in range(500):
    try:
        results[i] = dddm.load_nestle_samples(
            "../../results/nestle", i)
        print()
    except FileNotFoundError:
        pass
# Out:
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle0/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle1/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle2/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle3/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle4/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle5/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle6/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle7/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle8/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle9/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle10/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle11/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle12/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle13/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle14/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle15/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle16/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle17/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle73/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle80/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle89/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle91/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle99/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle100/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle109/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle110/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle111/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle112/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle113/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle114/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle115/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle117/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle119/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle120/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle121/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle122/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle123/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle124/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle125/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle126/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle127/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle128/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle129/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle130/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle131/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle132/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle134/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle135/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle136/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle138/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle139/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle141/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle142/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle144/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle145/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle146/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle147/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle148/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle149/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle150/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle152/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle153/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle155/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle156/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle157/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle158/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle159/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle161/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle162/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle163/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle164/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle165/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle167/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle168/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle169/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle170/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle171/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle172/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle173/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle176/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle177/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle178/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle179/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle180/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle181/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle182/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle183/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle184/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle186/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle187/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle188/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle189/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle190/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle191/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle192/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle193/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle194/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle195/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle197/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle198/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle199/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle200/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle201/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle202/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle203/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle204/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle205/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle206/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle207/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle209/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle210/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle211/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle212/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle214/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle215/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle216/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle218/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle219/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle220/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle221/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle222/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle223/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle225/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle226/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle227/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle231/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle232/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle233/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle234/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle236/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle237/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle238/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle239/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle243/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle244/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle245/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle246/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle248/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle258/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle259/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle260/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle261/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle262/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle263/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle264/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle265/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle266/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle267/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle268/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle269/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle270/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle271/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle272/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle273/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle274/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle275/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle276/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle277/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle278/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle279/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle280/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle281/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle282/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle283/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle284/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle285/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle286/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle287/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle288/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle289/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle290/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle291/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle292/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle293/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle294/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle295/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle296/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle297/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle298/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle299/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle300/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle301/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle302/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle303/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle304/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ...
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle373/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle374/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle375/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle376/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle377/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle378/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle379/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle380/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle381/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle382/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle383/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle384/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle385/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle386/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle387/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle388/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle389/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle390/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle391/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle392/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle393/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle394/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle395/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle396/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle397/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle398/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle399/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle400/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle401/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle402/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle403/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle404/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle405/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle406/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle407/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle408/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle409/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle410/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle411/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle412/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle413/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle414/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle415/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle416/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle417/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle418/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle419/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle420/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle421/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle422/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle423/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle424/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle425/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle426/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle427/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle428/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle429/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle430/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle431/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle432/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']
#
# load_nestle_samples::	2020-01-20T09:03
# 	loading results/../../results/nestle433/
# load_nestle_samples::	2020-01-20T09:03
# 	done loading
# access result with:
# ['config', 'res_dict', 'h', 'logl', 'logvol', 'logz', 'logzerr', 'ncall', 'niter', 'samples', 'weights']

# %%
def get_posterior(samples, weights):
    # re-scale weights to have a maximum of one
    nweights = weights/np.max(weights)

    # get the probability of keeping a sample from the weights
    keepidx = np.where(np.random.rand(len(nweights)) < nweights)[0]
    # get the posterior samples
    return samples[keepidx,:]

# %%
def bin_center(xedges, yedges):
    return 0.5 * (xedges[0:-1] + xedges[1:]), 0.5 * (yedges[0:-1] + yedges[1:])

# %%
def get_hist(item, nbins = 45, bin_range = None):
#     nbins = 45
#     bin_range = [[1, 3], [-46, -44]]
    if bin_range == None:
        bin_range = [results[item]['config']['prior']['log_mass']['range'],
                 results[item]['config']['prior']['log_cross_section']['range']
                ]
    counts, xedges, yedges = np.histogram2d(*get_p_i(item), bins = nbins, range = bin_range)
    return counts , xedges, yedges

def get_hist_norm(item):
    counts , xedges, yedges = get_hist(item)
    return counts/np.sum(counts) , xedges, yedges

# %%
# # fig = plt.figure(figsize=(7, 3))
# # ax = fig.add_subplot(131, title='imshow: square bins')
# from matplotlib.colors import LogNorm
# plt.imshow(test.T/np.sum(test.T), interpolation='nearest', origin='low',
#         extent=  [1, 3, -45.7, -44.3], norm=LogNorm())
# # plt.legend()
# plt.colorbar()

# %%
def get_p_i(i):
    m, sig = get_posterior(results[i]['samples'], results[i]['weights']).T[:2]
    return np.array([m, sig])

# %%
from matplotlib.colors import LogNorm
def combine_normalized(items, **plot_kwargs):
    X, Y = np.meshgrid(*get_hist_norm(items[0])[1:])
    for i in items:
        c,_,_ = get_hist_norm(i)
        im = plt.pcolor(X,Y,c.T, norm=LogNorm(vmin = 1e-4,vmax = 1),**plot_kwargs)  
    plt.colorbar()

# %%
def pow10(x):
    return 10 ** x

# %%
def confidence_plot(items, text_box = False, bin_range = None, nsigma = 2):
    fig,ax=plt.subplots(figsize = (8,6))
    if bin_range == None:
        bin_range = [results[items[0]]['config']['prior']['log_mass']['range'],
                 results[items[0]]['config']['prior']['log_cross_section']['range']
                ]
    
    for k, item in enumerate(items):#, 78, 110 
        x,y =get_p_i(item)
        # Make a 2d normed histogram
        H,xedges,yedges=np.histogram2d(x,y,bins=50, range = bin_range, normed=True)
        norm=H.sum() # Find the norm of the sum
        # Set contour levels
        contour3=0.99
        contour2=0.95
        contour1=0.68
        # Take histogram bin membership as proportional to Likelihood
        # This is true when data comes from a Markovian process
        def objective(limit, target):
            w = np.where(H>limit)
            count = H[w]
            return count.sum() - target
        target1 = norm*contour1
        level1= scipy.optimize.bisect(objective, H.min(), H.max(), args=(target1,))
        levels=[level1]
        if nsigma>1:
            target2 = norm*contour2
            level2= scipy.optimize.bisect(objective, H.min(), H.max(), args=(target2,))
            levels.append(level2)
            if nsigma>2:
                target3 = norm*contour3
                level3= scipy.optimize.bisect(objective, H.min(), H.max(), args=(target3,))    
                levels.append(level3)
            if nsigma>3:
                print('Nsigma too big')
        levels.reverse()
        levels.append(H.max())
        # Find levels by summing histogram to objective
        
        
        

#         levels=[level1, level2, level3,H.max()]
        # Pass levels to normed kde plot
        def av_levels(x):
            return [(x[i] + x[i+1])/2 for i in range(len(x)-1)]

        if levels[0]==levels[1]:
            print("ERRRRRRRRR\n\n")
            print(levels)
            levels[0] /= 1.01
            levels = np.unique(levels)
            print(levels)
        sns_ax = sns.kdeplot(x,y, shade=True,ax=ax,n_levels=levels,cmap="viridis",normed=True, 
                    cbar = False, vmin=levels[0], vmax=levels[-1])
        kwargs = {}
        if k is 0:
            kwargs['label'] = 'best fit'
        plt.scatter(np.mean(x),np.mean(y), c='black',
                    marker = '+',**kwargs)
        if k is 0:
            kwargs['label'] = 'benchmark value'
        plt.scatter(results[item]['config']['mw'],
                    results[item]['config']['sigma'], c='blue',
                    marker = 'x',
                    **kwargs)
        if k is 0:
            cbar = ax.figure.colorbar(sns_ax.collections[0])
            cbar.set_ticks(av_levels(np.linspace(0,1,nsigma+1)))
            col_labels = ['$3\sigma$', '$2\sigma$', '$1\sigma$'][3-nsigma:]
            cbar.set_ticklabels(col_labels)
            cbar.set_label("Posterior probability")
    secax = ax.secondary_xaxis('top', functions=(pow10, np.log10))
    if 'migd' in results[items[0]]['config']['detector']:
        x_ticks = [0.01, 0.1, 1, 3]
    else:
        x_ticks = [15, 25, 50, 100, 250, 500, 1000]
    for x_tick in x_ticks:
        ax.axvline(np.log10(x_tick), alpha = 0.1)
    secax.set_ticks(x_ticks)
    plt.xlim(np.log10(x_ticks[0]),np.log10(x_ticks[-1]))
    plt.xlabel("$\log_{10}(M_{\chi}$ $[GeV/c^{2}]$)")
    secax.set_xlabel("$M_{\chi}$ $[GeV/c^{2}]$")
    plt.ylabel("$\log_{10}(\sigma_{S.I.}$ $[cm^{2}]$)")
    plt.legend(loc = 'upper right')

    if text_box:
        plt.text(0.05, 0.95, text_box, 
                 bbox=dict(facecolor="white",
                           boxstyle="round"), 
                 transform=ax.transAxes,
                 alpha=0.5)
#     plt.show()

# %%
# for key in results.keys():
# # for key in selected_keys:
#     print(f"---{key}---")
#     result = results[key]
#     try:
#         print('earth_shielding',result['config']['earth_shielding'])
#         dddm.nestle_corner(result, save = f"../results/nestle{key}/")
#     except KeyError:
#         pass

# %%
# assert False

# %%
def results_to_df(res):
    df = pd.DataFrame()
    items = sorted(list(res.keys()))
    df['item'] = items
    for key in res[np.min(list(res.keys()))].keys():
        if key in ['samples', 'weights']:
            continue
        if key == 'config' or key == 'res_dict':
            for sub_key in res[items[0]][key].keys():
                if sub_key == 'prior':
                    for sub_sub_key in res[items[0]][key][sub_key].keys():
                        if type(res[items[0]][key][sub_key][sub_sub_key]) == dict:
                            for sub_sub_sub_key in res[items[0]][key][sub_key][sub_sub_key].keys():
                                df[key+'_'+sub_key+'_'+sub_sub_key+'_'+sub_sub_sub_key] = [res[it][key][sub_key][sub_sub_key][sub_sub_sub_key] for it in items]
                        else:
                            df[key+'_'+sub_key+'_'+sub_sub_key] = [res[it][key][sub_key][sub_sub_key] for it in items]
                else:
                    df[key+'_'+sub_key] = [res[it][key][sub_key] for it in items]
            
        else:
            df[key] = [res[it][key] for it in items]
        
            
    df['mw'] = 10 ** df['config_mw']
    df['n_fit_parameters'] = [len(pars) for pars in df['config_fit_parameters']]
    return df
df = results_to_df(results)
df.head(5)
# Out:
#    item config_detector  config_poisson  config_n_energy_bins config_prior_log_mass_range config_prior_log_mass_prior_type config_prior_log_mass_param                         config_prior_log_mass_dist config_prior_log_cross_section_range config_prior_log_cross_section_prior_type config_prior_log_cross_section_param                config_prior_log_cross_section_dist config_prior_density_range config_prior_density_prior_type  config_prior_density_mean  config_prior_density_std config_prior_density_param                          config_prior_density_dist config_prior_v_0_range config_prior_v_0_prior_type  config_prior_v_0_mean  config_prior_v_0_std config_prior_v_0_param                              config_prior_v_0_dist config_prior_v_esc_range config_prior_v_esc_prior_type  config_prior_v_esc_mean  config_prior_v_esc_std config_prior_v_esc_param                            config_prior_v_esc_dist config_prior_k_range config_prior_k_prior_type config_prior_k_param  \
# 0     0              Xe           False                    10                    [0.1, 3]                             flat                    [0.1, 3]  <function get_priors.<locals>.<lambda> at 0x7f...                           [-46, -42]                                      flat                           [-46, -42]  <function get_priors.<locals>.<lambda> at 0x7f...               [0.001, 0.9]                           gauss                        0.4                       0.1                 (0.4, 0.1)  <function get_priors.<locals>.<lambda> at 0x7f...              [80, 380]                       gauss                    230                    30              (230, 30)  <function get_priors.<locals>.<lambda> at 0x7f...               [379, 709]                         gauss                      544                    33.0                (544, 33)  <function get_priors.<locals>.<lambda> at 0x7f...           [0.5, 3.5]                      flat           [0.5, 3.5]
# 1     1              Ar           False                    10                    [0.1, 3]                             flat                    [0.1, 3]  <function get_priors.<locals>.<lambda> at 0x7e...                           [-46, -42]                                      flat                           [-46, -42]  <function get_priors.<locals>.<lambda> at 0x7e...               [0.001, 0.9]                           gauss                        0.4                       0.1                 (0.4, 0.1)  <function get_priors.<locals>.<lambda> at 0x7e...              [80, 380]                       gauss                    230                    30              (230, 30)  <function get_priors.<locals>.<lambda> at 0x7e...               [379, 709]                         gauss                      544                    33.0                (544, 33)  <function get_priors.<locals>.<lambda> at 0x7e...           [0.5, 3.5]                      flat           [0.5, 3.5]
# 2     2              Ge           False                    10                    [0.1, 3]                             flat                    [0.1, 3]  <function get_priors.<locals>.<lambda> at 0x7f...                           [-46, -42]                                      flat                           [-46, -42]  <function get_priors.<locals>.<lambda> at 0x7f...               [0.001, 0.9]                           gauss                        0.4                       0.1                 (0.4, 0.1)  <function get_priors.<locals>.<lambda> at 0x7f...              [80, 380]                       gauss                    230                    30              (230, 30)  <function get_priors.<locals>.<lambda> at 0x7f...               [379, 709]                         gauss                      544                    33.0                (544, 33)  <function get_priors.<locals>.<lambda> at 0x7f...           [0.5, 3.5]                      flat           [0.5, 3.5]
# 3     3              Ge           False                    10                    [0.1, 3]                             flat                    [0.1, 3]  <function get_priors.<locals>.<lambda> at 0x7f...                           [-46, -42]                                      flat                           [-46, -42]  <function get_priors.<locals>.<lambda> at 0x7f...               [0.001, 0.9]                           gauss                        0.4                       0.1                 (0.4, 0.1)  <function get_priors.<locals>.<lambda> at 0x7f...              [80, 380]                       gauss                    230                    30              (230, 30)  <function get_priors.<locals>.<lambda> at 0x7f...               [379, 709]                         gauss                      544                    33.0                (544, 33)  <function get_priors.<locals>.<lambda> at 0x7f...           [0.5, 3.5]                      flat           [0.5, 3.5]
# 4     4              Xe           False                    10                    [0.1, 3]                             flat                    [0.1, 3]  <function get_priors.<locals>.<lambda> at 0x7f...                           [-46, -42]                                      flat                           [-46, -42]  <function get_priors.<locals>.<lambda> at 0x7f...               [0.001, 0.9]                           gauss                        0.4                       0.1                 (0.4, 0.1)  <function get_priors.<locals>.<lambda> at 0x7f...              [80, 380]                       gauss                    230                    30              (230, 30)  <function get_priors.<locals>.<lambda> at 0x7f...               [379, 709]                         gauss                      544                    33.0                (544, 33)  <function get_priors.<locals>.<lambda> at 0x7f...           [0.5, 3.5]                      flat           [0.5, 3.5]
#
#                                  config_prior_k_dist  config_v_0  config_v_esc  config_density  config_mw  config_sigma                                  config_halo_model                              config_spectrum_class                                  config_det_params                config_start       config_notes  config_fit_time          config_fit_parameters  res_dict_nestle_nposterior  res_dict_nestle_time  res_dict_nestle_logZ  res_dict_nestle_logZerr                                   res_dict_summary res_dict_log_mass_fit_res res_dict_mass_fit_res res_dict_log_cross_section_fit_res res_dict_cross_section_fit_res                   h                                               logl                                             logvol                 logz               logzerr   ncall  niter     mw  n_fit_parameters
# 0  <function get_priors.<locals>.<lambda> at 0x7f...         230           544             0.4    1.39794         -45.0  <DirectDmTargets.halo.SHM object at 0x7f968442...  <class 'DirectDmTargets.detector.DetectorSpect...  {'exp': 5.0, 'cut_eff': 0.8, 'nr_eff': 0.5, 'E...  2019-12-09 19:28:06.100509  nestle_update_wr3             6994  [log_mass, log_cross_section]                       11087                  6994            -16.884283                 0.039898  niter: 49679\nncall: 103633\nnsamples: 53775\n...            1.40 +/-  0.03          25.2 +/- 1.7                   -45.01 +/-  0.09             9.83e-46 +/- 2e-46   6.520366588136412  [-366394.39646435797, -365437.1243780611, -349...  [-8.317888234548317, -8.318132375173317, -8.31...  -16.884282615873257  0.039898450772639545  103633  49679   25.0                 2
# 1  <function get_priors.<locals>.<lambda> at 0x7e...         230           544             0.4    1.39794         -45.0  <DirectDmTargets.halo.SHM object at 0x7efc2004...  <class 'DirectDmTargets.detector.DetectorSpect...  {'exp': 10.0, 'cut_eff': 0.8, 'nr_eff': 0.8, '...  2019-12-09 19:23:53.288767  nestle_update_wr1             8834  [log_mass, log_cross_section]                       11311                  8834            -14.798022                 0.035653  niter: 44447\nncall: 96063\nnsamples: 48543\nl...            1.42 +/-  0.06          26.1 +/- 3.4                   -45.05 +/-  0.21           8.96e-46 +/- 4.2e-46   5.206429620202034  [-149118.78035890442, -145153.98715434413, -14...  [-8.317888234548317, -8.318132375173317, -8.31...  -14.798021893230638   0.03565250315888966   96063  44447   25.0                 2
# 2  <function get_priors.<locals>.<lambda> at 0x7f...         230           544             0.4    1.39794         -45.0  <DirectDmTargets.halo.SHM object at 0x7fdecd09...  <class 'DirectDmTargets.detector.DetectorSpect...  {'exp': 3.0, 'cut_eff': 0.8, 'nr_eff': 0.9, 'E...  2019-12-09 19:26:00.284443  nestle_update_wr2             8727  [log_mass, log_cross_section]                       11052                  8727            -18.284365                 0.041103  niter: 51267\nncall: 106368\nnsamples: 55363\n...            1.40 +/-  0.02          25.2 +/- 1.3                   -45.00 +/-  0.05           9.91e-46 +/- 1.2e-46   6.919854876208783  [-311555.84899295087, -307650.93764859706, -30...  [-8.317888234548317, -8.318132375173317, -8.31...   -18.28436469289352  0.041102526618042715  106368  51267   25.0                 2
# 3  <function get_priors.<locals>.<lambda> at 0x7f...         230           544             0.4    2.39794         -45.0  <DirectDmTargets.halo.SHM object at 0x7f5eec9e...  <class 'DirectDmTargets.detector.DetectorSpect...  {'exp': 3.0, 'cut_eff': 0.8, 'nr_eff': 0.9, 'E...  2019-12-09 19:27:05.242117  nestle_update_wr2             8813  [log_mass, log_cross_section]                        9067                  8813            -24.798105                 0.033095  niter: 40272\nncall: 81834\nnsamples: 44368\nl...            2.53 +/-  0.25         342 +/- 2e+02                   -44.87 +/-  0.22           1.34e-45 +/- 6.8e-46  4.4862844721602215  [-319912.6904560832, -312591.9511526104, -3092...  [-8.317888234548317, -8.318132375173317, -8.31...  -24.798105100910018  0.033095079618592725   81834  40272  250.0                 2
# 4  <function get_priors.<locals>.<lambda> at 0x7f...         230           544             0.4    2.39794         -45.0  <DirectDmTargets.halo.SHM object at 0x7f7c9dab...  <class 'DirectDmTargets.detector.DetectorSpect...  {'exp': 5.0, 'cut_eff': 0.8, 'nr_eff': 0.5, 'E...  2019-12-09 19:29:11.836046  nestle_update_wr3             9287  [log_mass, log_cross_section]                        9001                  9287            -21.619130                 0.032977  niter: 39761\nncall: 88890\nnsamples: 43857\nl...            2.51 +/-  0.28       327 +/- 2.1e+02                   -44.88 +/-  0.25            1.3e-45 +/- 7.4e-46   4.454244798036587  [-360335.917546748, -345707.23338038573, -3421...  [-8.317888234548317, -8.318132375173317, -8.31...  -21.619129507185015  0.032976690387236426   88890  39761  250.0                 2

# %%
show_items = ['item','mw', 'config_sigma', 'res_dict_nestle_nposterior',
                   'config_notes', 'config_halo_model', 'n_fit_parameters', 'res_dict_nestle_time']

# %%
mask0 = df['config_detector'] == 'Xe_migd'
# mask2= df[mask]['res_dict_nestle_nposterior'] > 500
# selection = df[mask][mask2]['item'].values
mask1 = ~np.array(['multinest' in note for note in df[mask0]['config_notes'].values])
mask2 = ['final' in note for note in df[mask0][mask1]['config_notes'].values]
results_df = df[mask0][mask1]#[mask2]
results_df[show_items]
# Out:
#      item   mw  config_sigma  res_dict_nestle_nposterior                                config_notes                                  config_halo_model  n_fit_parameters  res_dict_nestle_time
# 18     73  0.1         -39.0                         422              nestle_16th_migdal_long_full_7  <DirectDmTargets.halo.SHM object at 0x7f30b1cb...                 2                 25015
# 19     80  0.1         -39.0                         516              nestle_16th_migdal_long_full_6  <DirectDmTargets.halo.SHM object at 0x7fcf8e19...                 5                 34499
# 20     89  0.1         -38.0                         504             nestle_16th_migdal_long_full_14  <DirectDmTargets.halo.SHM object at 0x7fc38cc3...                 5                 33547
# 21     91  0.1         -38.0                         405             nestle_16th_migdal_long_full_15  <DirectDmTargets.halo.SHM object at 0x7fa41153...                 2                 26948
# 22     99  0.1         -39.0                         991              nestle_16th_migdal_long_full_8  <DirectDmTargets.halo.SHM object at 0x7f90781d...                 5                 67355
# ..    ...  ...           ...                         ...                                         ...                                                ...               ...                   ...
# 309   429  3.0         -38.0                          72    nestle_17jan_final_results_3rd-nlive_505                                                shm                 5                 63517
# 310   430  3.0         -38.0                         307  nestle_17jan_final_results_2nd-nlive_20059                                                shm                 5                 24916
# 311   431  1.0         -32.0                          49    nestle_17jan_final_results_3rd-nlive_507                                       shielded_shm                 2                 62088
# 312   432  0.1         -38.0                         209  nestle_17jan_final_results_3rd-nlive_20027                                       shielded_shm                 5                 52386
# 313   433  1.0         -38.0                         471  nestle_17jan_final_results_2nd-nlive_30079                                                shm                 2                 76709
#
# [279 rows x 8 columns]

# %%
mask3 = np.array(['_50' in note for note in results_df['config_notes'].values])

results_df[mask3][show_items]
# Out:
#      item   mw  config_sigma  res_dict_nestle_nposterior                               config_notes config_halo_model  n_fit_parameters  res_dict_nestle_time
# 168   288  0.1         -32.0                          54       nestle_17jan_final_results-nlive_509               shm                 5                  3778
# 169   289  0.1         -38.0                          45       nestle_17jan_final_results-nlive_503               shm                 5                  3406
# 172   292  0.1         -38.0                          49   nestle_17jan_final_results_2nd-nlive_509               shm                 5                  3412
# 175   295  0.1         -32.0                          52      nestle_17jan_final_results-nlive_5012      shielded_shm                 2                 19786
# 176   296  0.1         -38.0                          54   nestle_17jan_final_results_2nd-nlive_500      shielded_shm                 2                 15109
# 179   299  0.1         -32.0                          54  nestle_17jan_final_results_2nd-nlive_5012      shielded_shm                 2                  8967
# 181   301  0.1         -32.0                          47  nestle_17jan_final_results_2nd-nlive_5018               shm                 2                  3260
# 182   302  0.1         -32.0                          46  nestle_17jan_final_results_2nd-nlive_5021               shm                 5                  3447
# 183   303  0.1         -38.0                          48   nestle_17jan_final_results_2nd-nlive_503      shielded_shm                 5                 21075
# 184   304  1.0         -38.0                          76       nestle_17jan_final_results-nlive_504               shm                 5                 27915
# 192   312  0.1         -32.0                          46      nestle_17jan_final_results-nlive_5015      shielded_shm                 5                 35021
# 194   314  0.1         -32.0                          47  nestle_17jan_final_results_2nd-nlive_5015      shielded_shm                 5                 17691
# 196   316  1.0         -38.0                          80  nestle_17jan_final_results_2nd-nlive_5010               shm                 5                 27249
# 198   318  3.0         -38.0                          83       nestle_17jan_final_results-nlive_505               shm                 5                 43188
# 204   324  3.0         -38.0                          87  nestle_17jan_final_results_2nd-nlive_5011               shm                 5                 45587
# 214   334  1.0         -38.0                          75   nestle_17jan_final_results_2nd-nlive_501      shielded_shm                 2                 79440
# 217   337  1.0         -32.0                          84  nestle_17jan_final_results_2nd-nlive_5019               shm                 2                 66060
# 219   339  3.0         -38.0                          79       nestle_17jan_final_results-nlive_502      shielded_shm                 2                  5526
# 220   340  1.0         -38.0                          77       nestle_17jan_final_results-nlive_501      shielded_shm                 2                  8108
# 221   341  3.0         -32.0                          77  nestle_17jan_final_results_2nd-nlive_5020               shm                 2                 70802
# 226   346  3.0         -38.0                          77   nestle_17jan_final_results_2nd-nlive_502      shielded_shm                 2                 13576
# 253   373  1.0         -38.0                          92   nestle_17jan_final_results_2nd-nlive_504      shielded_shm                 5                 54504
# 254   374  0.1         -38.0                          57   nestle_17jan_final_results_3rd-nlive_500               shm                 2                  3181
# 255   375  1.0         -38.0                          84       nestle_17jan_final_results-nlive_504      shielded_shm                 5                 67842
# 264   384  0.1         -38.0                          55   nestle_17jan_final_results_3rd-nlive_503               shm                 5                  3695
# 266   386  3.0         -38.0                          74   nestle_17jan_final_results_2nd-nlive_505      shielded_shm                 5                 69762
# 267   387  1.0         -38.0                          78   nestle_17jan_final_results_3rd-nlive_501               shm                 2                 21883
# 278   398  0.1         -38.0                          54   nestle_17jan_final_results_3rd-nlive_500      shielded_shm                 2                  9997
# 280   400  3.0         -38.0                          78       nestle_17jan_final_results-nlive_505      shielded_shm                 5                 12791
# 283   403  1.0         -32.0                          52  nestle_17jan_final_results_2nd-nlive_5013      shielded_shm                 2                 82802
# 284   404  0.1         -32.0                          47   nestle_17jan_final_results_3rd-nlive_506      shielded_shm                 2                  6646
# 285   405  0.1         -38.0                          46   nestle_17jan_final_results_3rd-nlive_503      shielded_shm                 5                 13205
# 286   406  1.0         -38.0                          73   nestle_17jan_final_results_3rd-nlive_504               shm                 5                 27098
# 287   407  3.0         -38.0                          73   nestle_17jan_final_results_3rd-nlive_502               shm                 2                 36266
# 292   412  0.1         -32.0                          48   nestle_17jan_final_results_3rd-nlive_506               shm                 2                  2612
# 293   413  0.1         -32.0                          49   nestle_17jan_final_results_3rd-nlive_509      shielded_shm                 5                 20569
# 296   416  0.1         -32.0                          53   nestle_17jan_final_results_3rd-nlive_509               shm                 5                  2683
# 309   429  3.0         -38.0                          72   nestle_17jan_final_results_3rd-nlive_505               shm                 5                 63517
# 311   431  1.0         -32.0                          49   nestle_17jan_final_results_3rd-nlive_507      shielded_shm                 2                 62088

# %%
np.unique(results_df[mask3]['config_halo_model'].values)
# Out:
# array(['shielded_shm', 'shm'], dtype=object)

# %%
# mask4A = results_df[mask3]['config_halo_model'] == 'shielded_shm'
# mask4B = np.array(['VerneSHM' in model for model in results_df[mask3]['config_halo_model'].values])
# mask4 = (mask4A) | (mask4B)
# test = results_df[mask3][mask4][show_items]
# test[test['n_fit_parameters'] == 5][show_items]

# %%
mask4 = results_df[mask3]['config_sigma'] == -38
mask5 = results_df[mask3][mask4]['config_mw'] == 0

sel_df = results_df[mask3][mask4][mask5][show_items]
sel_df
# Out:
#      item   mw  config_sigma  res_dict_nestle_nposterior                               config_notes config_halo_model  n_fit_parameters  res_dict_nestle_time
# 184   304  1.0         -38.0                          76       nestle_17jan_final_results-nlive_504               shm                 5                 27915
# 196   316  1.0         -38.0                          80  nestle_17jan_final_results_2nd-nlive_5010               shm                 5                 27249
# 214   334  1.0         -38.0                          75   nestle_17jan_final_results_2nd-nlive_501      shielded_shm                 2                 79440
# 220   340  1.0         -38.0                          77       nestle_17jan_final_results-nlive_501      shielded_shm                 2                  8108
# 253   373  1.0         -38.0                          92   nestle_17jan_final_results_2nd-nlive_504      shielded_shm                 5                 54504
# 255   375  1.0         -38.0                          84       nestle_17jan_final_results-nlive_504      shielded_shm                 5                 67842
# 267   387  1.0         -38.0                          78   nestle_17jan_final_results_3rd-nlive_501               shm                 2                 21883
# 286   406  1.0         -38.0                          73   nestle_17jan_final_results_3rd-nlive_504               shm                 5                 27098

# %%
def find_largest_posterior(df, sig = -38, mw = 1):
    items = []
    for nparam in [2,5]:
        for halo in ['shm', 'shielded_shm']:
            mask = (
                (df['n_fit_parameters'] == nparam) & 
                (df['config_halo_model'] == halo) &
                (df['mw'] == mw) &
                (df['config_sigma'] == sig))
            sel_df = df[mask].sort_values('res_dict_nestle_nposterior')
            
            maskA = sel_df['config_halo_model'] == 'shielded_shm'
            maskB = np.array(['VerneSHM' in model for model in sel_df['config_halo_model'].values])
            mask2 = maskA | maskB
            print(np.sum(maskA), np.sum(maskB), np.sum(mask2))
            if halo == 'shielded_shm':
                sel_df = sel_df[mask2]
            else:
                sel_df = sel_df[~mask2]
            print(f'{halo} for {nparam} pars @ s = {sig}, m = {mw}')
            if len(sel_df):
                print(sel_df[['item', 'mw', 'config_sigma', 'res_dict_nestle_nposterior']][-2:-1])
                items.append(sel_df['item'].values[-1])
    return items

# %%
selection = find_largest_posterior(results_df[mask3])
# Out:
# 0 0 0
# shm for 2 pars @ s = -38, m = 1
# Empty DataFrame
# Columns: [item, mw, config_sigma, res_dict_nestle_nposterior]
# Index: []
# 2 0 2
# shielded_shm for 2 pars @ s = -38, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 214   334  1.0         -38.0                          75
# 0 0 0
# shm for 5 pars @ s = -38, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 184   304  1.0         -38.0                          76
# 2 0 2
# shielded_shm for 5 pars @ s = -38, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 255   375  1.0         -38.0                          84

# %%
df_at_mw_sig = pd.concat([df[df['item'] == item] for item in selection]
)
df_at_mw_sig[show_items+['res_dict_mass_fit_res', 'res_dict_cross_section_fit_res']]
# Out:
#      item   mw  config_sigma  res_dict_nestle_nposterior                               config_notes config_halo_model  n_fit_parameters  res_dict_nestle_time res_dict_mass_fit_res res_dict_cross_section_fit_res
# 267   387  1.0         -38.0                          78   nestle_17jan_final_results_3rd-nlive_501               shm                 2                 21883         1.03 +/- 0.27           9.72e-39 +/- 1.5e-38
# 220   340  1.0         -38.0                          77       nestle_17jan_final_results-nlive_501      shielded_shm                 2                  8108         1.07 +/- 0.23           5.13e-39 +/- 5.8e-39
# 196   316  1.0         -38.0                          80  nestle_17jan_final_results_2nd-nlive_5010               shm                 5                 27249         1.04 +/- 0.22           6.44e-39 +/- 7.5e-39
# 253   373  1.0         -38.0                          92   nestle_17jan_final_results_2nd-nlive_504      shielded_shm                 5                 54504          1.09 +/- 0.2           4.83e-39 +/- 4.8e-39

# %%
df_at_mw_sig.keys().values
# Out:
# array(['item', 'config_detector', 'config_poisson',
#        'config_n_energy_bins', 'config_prior_log_mass_range',
#        'config_prior_log_mass_prior_type', 'config_prior_log_mass_param',
#        'config_prior_log_mass_dist',
#        'config_prior_log_cross_section_range',
#        'config_prior_log_cross_section_prior_type',
#        'config_prior_log_cross_section_param',
#        'config_prior_log_cross_section_dist',
#        'config_prior_density_range', 'config_prior_density_prior_type',
#        'config_prior_density_mean', 'config_prior_density_std',
#        'config_prior_density_param', 'config_prior_density_dist',
#        'config_prior_v_0_range', 'config_prior_v_0_prior_type',
#        'config_prior_v_0_mean', 'config_prior_v_0_std',
#        'config_prior_v_0_param', 'config_prior_v_0_dist',
#        'config_prior_v_esc_range', 'config_prior_v_esc_prior_type',
#        'config_prior_v_esc_mean', 'config_prior_v_esc_std',
#        'config_prior_v_esc_param', 'config_prior_v_esc_dist',
#        'config_prior_k_range', 'config_prior_k_prior_type',
#        'config_prior_k_param', 'config_prior_k_dist', 'config_v_0',
#        'config_v_esc', 'config_density', 'config_mw', 'config_sigma',
#        'config_halo_model', 'config_spectrum_class', 'config_det_params',
#        'config_start', 'config_notes', 'config_fit_time',
#        'config_fit_parameters', 'res_dict_nestle_nposterior',
#        'res_dict_nestle_time', 'res_dict_nestle_logZ',
#        'res_dict_nestle_logZerr', 'res_dict_summary',
#        'res_dict_log_mass_fit_res', 'res_dict_mass_fit_res',
#        'res_dict_log_cross_section_fit_res',
#        'res_dict_cross_section_fit_res', 'h', 'logl', 'logvol', 'logz',
#        'logzerr', 'ncall', 'niter', 'mw', 'n_fit_parameters'],
#       dtype=object)

# %%
df_at_mw_sig[]

# %%
df_at_mw_sig[['mw', 'config_sigma', 'config_halo_model', 'n_fit_parameters','res_dict_mass_fit_res', 'res_dict_cross_section_fit_res']].sort_values('config_halo_model')
# Out:
#       mw  config_sigma config_halo_model  n_fit_parameters res_dict_mass_fit_res res_dict_cross_section_fit_res
# 220  1.0         -38.0      shielded_shm                 2         1.07 +/- 0.23           5.13e-39 +/- 5.8e-39
# 253  1.0         -38.0      shielded_shm                 5          1.09 +/- 0.2           4.83e-39 +/- 4.8e-39
# 267  1.0         -38.0               shm                 2         1.03 +/- 0.27           9.72e-39 +/- 1.5e-38
# 196  1.0         -38.0               shm                 5         1.04 +/- 0.22           6.44e-39 +/- 7.5e-39

# %%
det = 'Xe_migd'
# keys = [*results.keys()]
# keys.reverse()

for i in selection:
    note = results[i]['config']['notes']
    this_df = df[df['item'] == i]
    print(i, results[i]['config']['notes'],results[i]['config']['prior']['log_mass']['range'])
    print(this_df[['mw', 'config_sigma', 'n_fit_parameters', 'config_halo_model','res_dict_nestle_nposterior']])
    bin_range = [[-0.5, 0.5],[-40,-35]] if 'migd' in det else None
    confidence_plot([i], text_box = f'{det}-detector', nsigma = 2,
                   bin_range = bin_range)
    title = note.split('_')
    title[-1] = '50'
    title = ' '.join(title)
    title += '\n'
#     title += f'm={this_df["mw"].values[0]}'
#     title += f', s = {this_df["config_sigma"].values[0]}'
    title += f'model ={this_df["config_halo_model"].values[0]}'
    title += f', nfit={this_df["n_fit_parameters"].values[0]}'
#     title += f', s = {this_df["config_sigma"].values[0]}'
    plt.title(f'{title}')
    name = str(i) + title.replace('\n','-').replace(' ', '_')
    combine_normalized([i], **{"alpha" : 0.3})
    if bin_range:
        plt.xlim(*bin_range[0])
        plt.ylim(*bin_range[1])
    save_name =f"{det}_{name.replace(' ', '-')}"
    plt.savefig(f"figures/{save_name}.png", dpi =300, bbox_inches="tight")
    plt.savefig(f"figures/{save_name}.pdf", dpi =300, bbox_inches="tight")
    print(f'saved at {save_name}')
#     dddm.nestle_corner(results[i], save = save_name + 'corner')
    dddm.nestle_corner(results[i], save = 'figures/' +  save_name)
    plt.show()
# Out:
# 387 nestle_17jan_final_results_3rd-nlive_501 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 267  1.0         -38.0                 2               shm                          78
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_387nestle_17jan_final_results_3rd-nlive_50-model_=shm,_nfit=2
# 340 nestle_17jan_final_results-nlive_501 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 220  1.0         -38.0                 2      shielded_shm                          77
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_340nestle_17jan_final_results-nlive_50-model_=shielded_shm,_nfit=2
# 316 nestle_17jan_final_results_2nd-nlive_5010 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 196  1.0         -38.0                 5               shm                          80
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_316nestle_17jan_final_results_2nd-nlive_50-model_=shm,_nfit=5
# 373 nestle_17jan_final_results_2nd-nlive_504 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 253  1.0         -38.0                 5      shielded_shm                          92
# ERRRRRRRRR
#
#
# [6.024096385541136, 6.024096385541136, 48.19277108434005]
# [ 5.96445187  6.02409639 48.19277108]
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_373nestle_17jan_final_results_2nd-nlive_50-model_=shielded_shm,_nfit=5

# %%
selection2 = find_largest_posterior(df, sig = -38, mw = 1)
# Out:
# 0 0 0
# shm for 2 pars @ s = -38, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 251   371  1.0         -38.0                         303
# 4 0 4
# shielded_shm for 2 pars @ s = -38, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 245   365  1.0         -38.0                         153
# 0 0 0
# shm for 5 pars @ s = -38, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 265   385  1.0         -38.0                         326
# 3 0 3
# shielded_shm for 5 pars @ s = -38, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 255   375  1.0         -38.0                          84

# %%
df_at_mw_sig2 = pd.concat([results_df[results_df['item'] == item] for item in selection2]
)
df_at_mw_sig2[show_items+['res_dict_mass_fit_res', 'res_dict_cross_section_fit_res']]
# Out:
#      item   mw  config_sigma  res_dict_nestle_nposterior                                config_notes config_halo_model  n_fit_parameters  res_dict_nestle_time res_dict_mass_fit_res res_dict_cross_section_fit_res
# 313   433  1.0         -38.0                         471  nestle_17jan_final_results_2nd-nlive_30079               shm                 2                 76709         1.03 +/- 0.27           1.03e-38 +/- 1.6e-38
# 258   378  1.0         -38.0                         163  nestle_17jan_final_results_2nd-nlive_10025      shielded_shm                 2                 46453         1.11 +/- 0.26           4.35e-39 +/- 5.3e-39
# 288   408  1.0         -38.0                         479      nestle_17jan_final_results-nlive_30040               shm                 5                 22953         1.05 +/- 0.24           6.59e-39 +/- 8.9e-39
# 253   373  1.0         -38.0                          92    nestle_17jan_final_results_2nd-nlive_504      shielded_shm                 5                 54504          1.09 +/- 0.2           4.83e-39 +/- 4.8e-39

# %%
df_at_mw_sig2[['mw', 'config_sigma', 'config_halo_model', 'n_fit_parameters','res_dict_mass_fit_res', 'res_dict_cross_section_fit_res']].sort_values('config_halo_model')
# Out:
#       mw  config_sigma config_halo_model  n_fit_parameters res_dict_mass_fit_res res_dict_cross_section_fit_res
# 258  1.0         -38.0      shielded_shm                 2         1.11 +/- 0.26           4.35e-39 +/- 5.3e-39
# 253  1.0         -38.0      shielded_shm                 5          1.09 +/- 0.2           4.83e-39 +/- 4.8e-39
# 313  1.0         -38.0               shm                 2         1.03 +/- 0.27           1.03e-38 +/- 1.6e-38
# 288  1.0         -38.0               shm                 5         1.05 +/- 0.24           6.59e-39 +/- 8.9e-39

# %%
det = 'Xe_migd'
# keys = [*results.keys()]
# keys.reverse()

for i in selection2:
    note = results[i]['config']['notes']
    this_df = df[df['item'] == i]
    print(i, results[i]['config']['notes'],results[i]['config']['prior']['log_mass']['range'])
    print(this_df[['mw', 'config_sigma', 'n_fit_parameters', 'config_halo_model','res_dict_nestle_nposterior']])
    bin_range = [[-0.5, 0.5],[-40,-35]] if 'migd' in det else None
    confidence_plot([i], text_box = f'{det}-detector', nsigma = 1,
                   bin_range = bin_range)
    title = note.split('_')
    if len (title[-1]) > 3:
        title[-1] = title[-1][:-2]
    else:
        title[-1] = title[-1][:-1]
    title = ' '.join(title)
    title += '\n'
#     title += f'm={this_df["mw"].values[0]}'
#     title += f', s = {this_df["config_sigma"].values[0]}'
    title += f'model ={this_df["config_halo_model"].values[0]}'
    title += f', nfit={this_df["n_fit_parameters"].values[0]}'
#     title += f', s = {this_df["config_sigma"].values[0]}'
    plt.title(f'{title}')
    name = str(i) + title.replace('\n','-').replace(' ', '_')
    combine_normalized([i], **{"alpha" : 0.3})
    if bin_range:
        plt.xlim(*bin_range[0])
        plt.ylim(*bin_range[1])
    save_name =f"{det}_{name.replace(' ', '-')}"
    plt.savefig(f"figures/{save_name}.png", dpi =300, bbox_inches="tight")
    plt.savefig(f"figures/{save_name}.pdf", dpi =300, bbox_inches="tight")
    print(f'saved at {save_name}')
    dddm.nestle_corner(results[i], save = 'figures/' +  save_name)
    plt.show()
# Out:
# 433 nestle_17jan_final_results_2nd-nlive_30079 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 313  1.0         -38.0                 2               shm                         471
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_433nestle_17jan_final_results_2nd-nlive_300-model_=shm,_nfit=2
# 378 nestle_17jan_final_results_2nd-nlive_10025 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 258  1.0         -38.0                 2      shielded_shm                         163
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_378nestle_17jan_final_results_2nd-nlive_100-model_=shielded_shm,_nfit=2
# 408 nestle_17jan_final_results-nlive_30040 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 288  1.0         -38.0                 5               shm                         479
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_408nestle_17jan_final_results-nlive_300-model_=shm,_nfit=5
# 373 nestle_17jan_final_results_2nd-nlive_504 [-2, 1]
#       mw  config_sigma  n_fit_parameters config_halo_model  res_dict_nestle_nposterior
# 253  1.0         -38.0                 5      shielded_shm                          92
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/seaborn/distributions.py:423: UserWarning: The following kwargs were not used by contour: 'normed'
#   cset = contour_func(xx, yy, z, n_levels, **kwargs)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/matplotlib/scale.py:144: RuntimeWarning: divide by zero encountered in log10
#   return self._forward(values)
# saved at Xe_migd_373nestle_17jan_final_results_2nd-nlive_50-model_=shielded_shm,_nfit=5

# %%
find_largest_posterior(df, sig = -32)
# Out:
# 0 0 0
# shm for 2 pars @ s = -32, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 217   337  1.0         -32.0                          84
# 3 0 3
# shielded_shm for 2 pars @ s = -32, m = 1
#      item   mw  config_sigma  res_dict_nestle_nposterior
# 283   403  1.0         -32.0                          52
# 0 0.0 0
# shm for 5 pars @ s = -32, m = 1
# 0 0.0 0
# shielded_shm for 5 pars @ s = -32, m = 1
# [377, 415]

# %%
confidence_plot([337], bin_range=[[0,0.01], [-32.01,-31.99]])

# %%
det = 'Xe_migd'
keys = [*results.keys()]
keys.reverse()
for i in keys:
    note = results[i]['config']['notes']
    print(i, results[i]['config']['notes'],results[i]['config']['prior']['log_mass']['range'])
    bin_range = [[-2, 1],[-40,-35]] if 'migd' in note else None
    confidence_plot([i], text_box = f'{det}-detector', nsigma = 2,
                   bin_range = bin_range)
    plt.title(f'{note} \n')
    name = det + str(i)
    combine_normalized([i], **{"alpha" : 0.3})
    if bin_range:
        plt.xlim(*bin_range[0])
        plt.ylim(*bin_range[1])
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.png", dpi =300, bbox_inches="tight")
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.pdf", dpi =300, bbox_inches="tight")

    plt.show()

# %%
for i, name in enumerate(selected_keys_names):
    confidence_plot(selected_keys_sets[i], text_box = f'{det}-detector')
#     if "realistic" in name:
#     plt.ylim(-49, -45)
#     else:
    plt.ylim(-45.7, -44.3)
    plt.title(f'{name} \n')
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.png", dpi =300, bbox_inches="tight")
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.pdf", dpi =300, bbox_inches="tight")
    plt.show()
                
#     break

# %%
det = 'Ge'
mask = df['config_detector'] == det
sets = np.unique(df[mask]['config_notes'].values)
assert len(sets) == 2, "you have to manually select the keys since there are multiple sets in the query"
selected_keys_sets = [df[df['config_notes'] == _set]['item'].values for _set in sets] 
selected_keys_names = ["benchmark SHM constrained fit",
                      "benchmark SHM astr. unconstraint fit",
#                       "updated SHM constrained fit",
#                       "updated SHM astr. unconstraint fit"
                      ]
selected_keys_sets

# %%
for i, name in enumerate(selected_keys_names):
    confidence_plot(selected_keys_sets[i], text_box = f'{det}-detector')
    if "realistic" in name:
        plt.ylim(-49, -45)
    else:
        plt.ylim(-45.7, -44.3)
    plt.title(f'{name} \n')
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.png", dpi =300, bbox_inches="tight")
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.pdf", dpi =300, bbox_inches="tight")
    plt.show()

# %%
det = 'Xe'
mask = df['config_detector'] == det
sets = np.unique(df[mask]['config_notes'].values)
assert len(sets) == 2, "you have to manually select the keys since there are multiple sets in the query"
selected_keys_sets = [df[df['config_notes'] == _set]['item'].values for _set in sets] 
selected_keys_names = ["benchmark SHM constrained fit",
                      "benchmark SHM astr. unconstraint fit",
#                       "updated SHM constrained fit",
#                       "updated SHM astr. unconstraint fit"
                      ]
selected_keys_sets

for i, name in enumerate(selected_keys_names):
    confidence_plot(selected_keys_sets[i], text_box = f'{det}-detector')
    if "realistic" in name:
        plt.ylim(-49, -45)
    else:
        plt.ylim(-45.7, -44.3)
    plt.title(f'{name} \n')
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.png", dpi =300, bbox_inches="tight")
    plt.savefig(f"figures/{det}_{name.replace(' ', '-')}.pdf", dpi =300, bbox_inches="tight")
    plt.show()

# %%
def get_quantile(item):
    _, xedges, _ = get_hist(item, nbins = 1000)
    data = get_p_i(item)
    results = np.zeros((len(xedges),3))
#     print(results)
    for i in range(len(xedges) - 1):
#         print(bin_i)
        mask = (xedges[i] < data[0]) & (data[0] < xedges[i+1])
        if np.sum(mask)>0:
#             print()
            results[i] =  0.5 * (xedges[i]+ xedges[i+1]), *np.percentile(data[1][mask], [5,95])
    return results[results[:,0] > 0]

# %%
quantiles = get_quantile(0)
# quantiles = quantiles[quantiles]
plt.plot(quantiles[:,0],quantiles[:,1])
plt.plot(quantiles[:,0],quantiles[:,2])
# quantiles

# %%
counts = get_hist(0)[0]
centers = bin_center(*get_hist(0)[1:])

# %%
for count in counts.T:
    print(np.percentile(count, [5, 95]))

# %%
combine_normalized([0])
quantiles = get_quantile(0)
# quantiles = quantiles[quantiles]
plt.plot(quantiles[:,0],quantiles[:,1])
plt.plot(quantiles[:,0],quantiles[:,2])

# %%
np.shape(get_p_i(0)[:,])

# %%
test = get_p_i(0)
np.array(test)[:,:100]

# %%
confidence_plot(selected_keys)

# %%
# import numpy as np
# import scipy.optimize
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Generate some random data
# # x,y=np.random.randn(2,100000)
# fig,ax=plt.subplots(figsize = (8,6))
# for k, item in enumerate([74, 78, 110]):#, 78, 110 
#     x,y =get_p_i(item)
#     # Make a 2d normed histogram
#     H,xedges,yedges=np.histogram2d(x,y,bins=40,normed=True)

#     norm=H.sum() # Find the norm of the sum
#     # Set contour levels
#     contour1=0.99
#     contour2=0.95
#     contour3=0.68
#     # Take histogram bin membership as proportional to Likelihood
#     # This is true when data comes from a Markovian process
#     def objective(limit, target):
#         w = np.where(H>limit)
#         count = H[w]
#         return count.sum() - target
# #     contour={}
# #     target={}
# #     level={}
# #     sigmas = np.flip(range(2,4))
# #     for s in sigmas:
# #         contour[s] = sigma_to_p(s)
# #         print(contour[s])
# #         target[s]=norm*contour[s]
# #         level[s]=scipy.optimize.bisect(objective, H.min(), H.max(), args=(target[s],))
# #     # Set target levels as percentage of norm
#     target1 = norm*contour1
#     target2 = norm*contour2
#     target3 = norm*contour3



#     # Find levels by summing histogram to objective
#     level1= scipy.optimize.bisect(objective, H.min(), H.max(), args=(target1,))
#     level2= scipy.optimize.bisect(objective, H.min(), H.max(), args=(target2,))
#     level3= scipy.optimize.bisect(objective, H.min(), H.max(), args=(target3,))

#     # For nice contour shading with seaborn, define top level
# #     level[s+1]=H.max()
# #     levels=[level[s] for s in sigmas]
# #     levels.append(H.max())
#     levels=[level1, level2, level3,H.max()]
#     print(levels)
#     # Pass levels to normed kde plot
#     def av_levels(x):
#         return [(x[i] + x[i+1])/2 for i in range(len(x)-1)]
    
# #     sns_ax = sns.kdeplot(x,y, shade=True,ax=ax,n_levels=levels,cmap="viridis",normed=True, 
# #                 cbar = True, vmin=levels[0], vmax=levels[-1], 
# #                          cbar_kws={#"ticklocation":av_levels(levels),
# #                                    "ticks":[],
# #                                    #"format":">%s<"
# # #                                    "format":av_levels(levels)
# # #                                   "ticks":[1,3,4]
# #                                    "label":"significance"
# #                                   })
    
#     if levels[0]==levels[1]:
#         print("ERRRRRRRRR\n\n")
#         levels[0] /= 1.01
#     sns_ax = sns.kdeplot(x,y, shade=True,ax=ax,n_levels=levels,cmap="viridis",normed=True, 
#                 cbar = False, vmin=levels[0], vmax=levels[-1])
# #                          cbar_kws={#"ticklocation":av_levels(levels),
# #                                    "ticks":[],
# #                                    #"format":">%s<"
# # #                                    "format":av_levels(levels)
# # #                                   "ticks":[1,3,4]
# #                                    "label":"significance"
# #                                   })
#                             #          "labels":levels})
# #     fig.colorbar(cax,ticks=[-1, 0, 1])
# #     ax.set_aspect('equal')
#     kwargs = {}
#     if k is 0:
#         kwargs['label'] = 'best fit'
#     plt.scatter(np.mean(x),np.mean(y), c='black',
#                 marker = '+',**kwargs)
#     if k is 0:
#         kwargs['label'] = 'benchmark value'
#     plt.scatter(results[item]['config']['mw'],
#                 results[item]['config']['sigma'], c='blue',
#                 marker = 'x',
#                 **kwargs)
#     if k is 0:
#         cbar = ax.figure.colorbar(sns_ax.collections[0])
#     #     cbar = sns_ax.figure.colorbar()#[0].colorbar
#     #     print(av_levels(levels))
#     #     cbar.set_ticks(av_levels(levels))
#         cbar.set_ticks(av_levels(np.linspace(0,1,4)))
#     #     print(level1)
#         cbar.set_ticklabels(['$3\sigma$', '$2\sigma$', '$1\sigma$'])
#         cbar.set_label("Confidence interval")
#     #     cbar.set_nbins(4)
# secax = ax.secondary_xaxis('top', functions=(pow10, np.log10))
# # ax1.set_xticklabels([1])
# # ax.set_xlim(np.log10(10),np.log10(1000))
# x_ticks = [15, 25, 50, 100, 250, 500, 1000]
# for x_tick in x_ticks:
#     ax.axvline(np.log10(x_tick), alpha = 0.1)
# secax.set_ticks(x_ticks)
# plt.xlim(np.log10(x_ticks[0]),np.log10(x_ticks[-1]))
# plt.xlabel("$\log_{10}(M_{\chi}$ $[GeV/c^{2}]$)")
# secax.set_xlabel("$M_{\chi}$ $[GeV/c^{2}]$")
# plt.ylabel("$\log_{10}(\sigma_{S.I.}$ $[cm^{2}]$)")
# plt.legend()
# plt.show()

# %%
from scipy.special import erf
def sigma_to_p(x):
    return erf(x/np.sqrt(2))

for x in range(1,5):
    print(x, sigma_to_p(x))

# %%
combine_normalized(selection[0:2])

# %%
combine_normalized(selected_keys_sets[1])

# %%
np.percentile(np.linspace(0,100,100), [5,95])

# %%
items = selected_keys[:3]
def get_df(items):
#     df = pd.DataFrame()
    for j, item in enumerate(items):
        posteriors = get_p_i(item)
        test_df = pd.DataFrame()
        
        test_df['$\log(M_\chi)$'] = posteriors[0]
        test_df['$\log(\sigma)$'] = posteriors[1]
        test_df['mass'] = 10**results[item]['config']['mw']
#         sns.jointplot(x="x", y="y", data=test_df, kind="kde",
#                      ylim = [-46,-44],
#                      xlim = [1,3]);
        if j == 0:
            df = test_df
        else:
            df = pd.concat([df, test_df])
#     df = df.assign(industry='yyy')
    return df
data = get_df(items)
print(np.unique(data.mass), len(data))
data.head(3)

# %%
def plot_set(items, save_as):
    # data = sns.load_dataset('iris')
    # plt.figure(figsize=(15,10))
    data = get_df(items)
    print(np.unique(data.mass), len(data))
    def make_kde(*args, **kwargs):  
        #"cbar":True, 
    #     opts ={"n_levels":5}
        sns.kdeplot(n_levels = 3, *args, cmap=next(make_kde.cmap_cycle), **kwargs)

    def make_kde_cbar(*args, **kwargs):  
        #"cbar":True, 
    #     opts ={"n_levels":5}
        sns.kdeplot(n_levels = 3, cbar = True, *args, cmap=next(make_kde.cmap_cycle), **kwargs)
    kwargs ={"cbar":True, "n_levels":5}
    make_kde.cmap_cycle = cycle(('Blues_r', 'Oranges_r', 'Greens_r'))

    pg = sns.PairGrid(data, vars=('$\log(M_\chi)$', '$\log(\sigma)$'), hue='mass')
    pg.map_diag(sns.kdeplot)#, color = ({)'b', 'g', 'r'})
    pg.map_lower(make_kde)
    # pg.map_upper(make_kde_cbar)
    pg.fig.set_size_inches(15,10)
    pg.fig.savefig(f"{det}_{save_as}.png", dpi =300)
    pg.fig.savefig(f"{det}_{save_as}.pdf", dpi =300)
    plt.title(f"{save_as}")
    plt.show()

# %%
for k in range(len(selected_keys_names)):
    plot_set(selected_keys_sets[k], selected_keys_names[k])

# %%
# items = selected_keys[:3]
def get_df(items):
#     df = pd.DataFrame()
    for j, item in enumerate(items):
        posteriors = get_p_i(item)
        test_df = pd.DataFrame()
        
        test_df['$\log(M_\chi)$'] = posteriors[0]
        test_df['$\log(\sigma)$'] = posteriors[1]
        test_df['mass'] = 10**results[item]['config']['mw']
#         sns.jointplot(x="x", y="y", data=test_df, kind="kde",
#                      ylim = [-46,-44],
#                      xlim = [1,3]);
        if j == 0:
            df = test_df
        else:
            df = pd.concat([df, test_df])
#     df = df.assign(industry='yyy')
    return df

# %%
items = selected_keys_sets[0]
data = get_df(items)
print(np.unique(data.mass), len(data))
data.head(3)

# %%
# %%time
# data = sns.load_dataset('iris')
# plt.figure(figsize=(15,10))
def make_kde(*args, **kwargs):  
    #"cbar":True, 
#     opts ={"n_levels":5}
    sns.kdeplot(n_levels = 3, *args, cmap=next(make_kde.cmap_cycle), **kwargs)

def make_kde_cbar(*args, **kwargs):  
    #"cbar":True, 
#     opts ={"n_levels":5}
    sns.kdeplot(n_levels = 3, cbar = True, *args, cmap=next(make_kde.cmap_cycle), **kwargs)
kwargs ={"cbar":True, "n_levels":5}
make_kde.cmap_cycle = cycle(('Blues_r', 'Oranges_r', 'Greens_r'))

pg = sns.PairGrid(data, vars=('$\log(M_\chi)$', '$\log(\sigma)$'), hue='mass')
pg.map_diag(sns.kdeplot)#, color = ({)'b', 'g', 'r'})
pg.map_lower(make_kde)
# pg.map_upper(make_kde_cbar)
pg.fig.set_size_inches(15,10)
pg.fig.savefig(f"{det}_fixed_astroph.png", dpi =300)
pg.fig.savefig(f"{det}_fixed_astroph.pdf", dpi =300)

# %%
items = selected_keys_sets[0]
data = get_df(items)
print(np.unique(data.mass), len(data))
data.head(3)

# %%
# %%time
# data = sns.load_dataset('iris')
# plt.figure(figsize=(15,10))
def make_kde(*args, **kwargs):  
    #"cbar":True, 
#     opts ={"n_levels":5}
    sns.kdeplot(n_levels = 3, *args, cmap=next(make_kde.cmap_cycle), **kwargs)

def make_kde_cbar(*args, **kwargs):  
    #"cbar":True, 
#     opts ={"n_levels":5}
    sns.kdeplot(n_levels = 3, cbar = True, *args, cmap=next(make_kde.cmap_cycle), **kwargs)
kwargs ={"cbar":True, "n_levels":5}
make_kde.cmap_cycle = cycle(('Blues_r', 'Oranges_r', 'Greens_r'))

pg = sns.PairGrid(data, vars=('$\log(M_\chi)$', '$\log(\sigma)$'), hue='mass')
pg.map_diag(sns.kdeplot)#, color = ({)'b', 'g', 'r'})
pg.map_lower(make_kde)
# pg.map_upper(make_kde_cbar)
pg.fig.set_size_inches(15,10)
pg.fig.savefig(f"{det}_loose_astroph.png", dpi =300)
pg.fig.savefig(f"{det}_loose_astroph.pdf", dpi =300)

# %%
# np.shape(np.random.normal(1, 1, 10**6))

# %%
from scipy.stats.mstats import mquantiles

# %%
# x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style("white"):
    sns.jointplot(x=test[0], y=test[1], kind="hex", color="k");

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(test[0], test[1], ax=ax)
sns.rugplot(test[0], color="g", ax=ax)
sns.rugplot(test[1], vertical=True, ax=ax);

# %%
test_df = pd.DataFrame()
test_df['x'] = test[0]
test_df['y'] = test[1]

# %%
sns.jointplot(x="x", y="y", data=test_df, kind="kde");

# %%
items = selected_keys

def plot_posterior(items):
    posteriors = [get_p_i(item) for item in items]
    test_df = pd.DataFrame()

    test_df['x'] = np.concatenate([p[0] for p in posteriors])
    test_df['y'] = np.concatenate([p[1] for p in posteriors])
    sns.jointplot(x="x", y="y", data=test_df, kind="kde",
                 ylim = [-46,-44],
                 xlim = [1,3]);
plot_posterior(items)

# %%
items = selected_keys[:3]
def plot_posterior_per_item(items):
    for item in items:
        posteriors = get_p_i(item)
        test_df = pd.DataFrame()

        test_df['x'] = posteriors[0]
        test_df['y'] = posteriors[1]
        sns.jointplot(x="x", y="y", data=test_df, kind="kde",
                     ylim = [-46,-44],
                     xlim = [1,3]);
plot_posterior_per_item(items)

# %%
# items = selected_keys[:3]

# # sns.jointplot(x="x", y="y", data=test_df, kind="kde",
# #                      ylim = [-46,-44],
# #                      xlim = [1,3]);
# def plot_posterior_per_item(items):
#     for j, item in enumerate(items):
#         posteriors = get_p_i(item)
#         test_df = pd.DataFrame()

#         test_df[f'x'] = posteriors[0]
#         test_df[f'y'] = posteriors[1]
#         if j ==0:
            
#             grid = sns.JointGrid(x="x", y="y", data=test_df)
#         grid = grid.plot_joint(
#             sns.jointplot(x="x", y="y", data=test_df, kind="kde",
#                      ylim = [-46,-44],
#                      xlim = [1,3]));
# plot_posterior_per_item(items)

# %%
selected_keys

# %%
# %time
# items = results.keys()
# def get_p_i(i):
#     return get_posterior(results[i]['samples'], results[i]['weights']).T[:2]
# posteriors = [get_p_i(item) for item in items]
# test_df = pd.DataFrame()

# test_df['x'] = np.concatenate([p[0] for p in posteriors])
# test_df['y'] = np.concatenate([p[1] for p in posteriors])
# sns.jointplot(x="x", y="y", data=test_df, kind="kde",
#              ylim = [-46,-44],
#              xlim = [1,3]);
