# %%
import DirectDmTargets as dddm
# Out:
# calculating effective efficiency for Xe detector done
# calculating effective efficiency for Ge detector done
# calculating effective efficiency for Ar detector done

# %%
import wimprates as wr
wr.__version__
# Out:
# '0.3.2'

# %%
wr
# Out:
# <module 'wimprates' from '/data/xenon/joranang/software/wimprates/wimprates/__init__.py'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numericalunits as nu

# %%
from tqdm import tqdm

# %%
from scipy.integrate import quad as scipy_int

# %%
import pandas as pd

# %%
import scipy

# %% [markdown]
# # Direct detection of Dark matter using different target materials #
#
# Author:
#
# Joran Angevaare <j.angevaare@nikef.nl>
#
# Date:
#
# 14 october 2019
#
# ## Goal ##
#
# - Roughly reproduce <https://journals.aps.org/prd/abstract/10.1103/PhysRevD.83.083505>
# - Update the results thereof with more recent knowledge of the DM-distribution
#
# ### Approach ###
# To achieve these goals, we must first get a decent recoil spectrum, that is flexible enough to have different astrophysical parameters. Further, it must also be flexible enough to be able to allow for different analytic functions to be added to the model. For instance, we must be able to incorporate the $\rm{SHM}^{++}$ as presented here <https://arxiv.org/abs/1810.11468>.
#
# When we have a sufficiently flexible model, we want to add in the detector physics, we should therein incorporate at least the following parameters:
# - target
#   - material
#   - cross-section
# - threshold
# - background
# - cut efficiency
# - volume
# - exposure
#
# Finally we should perform the inference

# %% [markdown]
# ## HALO model ##

# %%
x = np.linspace(0,1000,200) * nu.km / nu.s
y2 = wr.observed_speed_dist(x, 0)
plt.plot(x/(nu.km / nu.s),y2)
# plt.axvline(310)
plt.xlabel("v [km/s]")
# plt.ylabel("$f (v)$")
# Out:
# /data/xenon/joranang/software/wimprates/wimprates/halo.py:144: RuntimeWarning: divide by zero encountered in true_divide
#   / (2 * v_earth_t * v))
# Text(0.5, 0, 'v [km/s]')

# %%
# NR's
energies = np.linspace(0.001, 100, 100)

# dr/dr
dr = wr.rate_wimp_std(energies, mw=50, sigma_nucleon=1e-45)

plt.plot(energies, dr, label="WIMPrates SHM")

plt.xlabel("Recoil energy [keV]")
plt.ylabel("Rate [events per (keV ton year)]")
plt.title("$m_\chi = 50$ GeV/c${}^2$, $\sigma_\chi = 10^{-45}$ cm${}^2$")
plt.xlim(0, energies.max())

use_SHM = dddm.SHM()
dr_shm = wr.rate_wimp_std(energies, mw=50, sigma_nucleon=1e-45, halo_model = use_SHM)
plt.plot(energies, dr_shm, label = "Modified SHM")
plt.yscale('log')
plt.legend()

# %%
# NR's
energies = np.linspace(0.1, 3.5, 10)

# dr/dr
dr = ((nu.keV * (1000 * nu.kg) * nu.year) * 
    wr.rate_migdal(energies * nu.keV, 
                    mw=1 * nu.GeV/nu.c0**2, 
                    sigma_nucleon=1e-35 * nu.cm**2))

plt.plot(energies, dr, label="WIMPrates SHM")

plt.xlabel("Recoil energy [keV]")
plt.ylabel("Rate [events per (keV ton year)]")

plt.xlim(0, energies.max())
plt.yscale("log")

plt.ylim(1e-7,1e10)
dr
# Out:
# array([3.31105804e+07, 5.49338416e+05, 4.28478772e+05, 8.09727825e+04,
#        1.48047796e+04, 2.79764292e+03, 4.83534974e+02, 6.04338789e+01,
#        2.04628946e+00, 0.00000000e+00])

# %%
dr
# Out:
# array([0., 0., 0., 0., 0.])

# %%
(nu.keV * (1000 * nu.kg) * nu.year)
# Out:
# 5.430716536845096e-07

# %% [markdown]
# ## Detector smearing

# %% [markdown]
# # Inference #
# Below we setup the inference

# %%
# import emcee
# emcee.__version__

# %% [markdown]
# ## Distribution of the DM ##
# First we need to make a DM-rate spectrum

# %%
def get_gal_spec(det):

    spec_class = dddm.GenSpectrum(50, 1e-45, use_SHM, dddm.detectors[det])
    spec_class.E_max = 200
    spec_class.mw = 50
    spec_class.n_bins = 200
    return spec_class.get_data(poisson = False)

# %%
# plot_spectrum(xe_galact, label = 'un-smeared', linestyle = '--')
fig,ax=plt.subplots(figsize = (8,6))
dddm.plot_spectrum(get_gal_spec('Xe'), 'red', label = 'Xe target ', plot_error = False)
dddm.plot_spectrum(get_gal_spec('Ge'), 'green', label = 'Ge target', plot_error = False)
dddm.plot_spectrum(get_gal_spec('Ar'), 'orange', label = 'Ar target', plot_error = False)
plt.yscale("log")
plt.xlabel("Recoil energy [keV]")
plt.ylabel("Rate [events per (keV ton year)]")
plt.legend()

# %%
def get_det_spec(det, mw =50):
    spec_class = dddm.DetectorSpectrum(50, 1e-45, use_SHM, dddm.detectors[det])
    spec_class.E_max = 200
    spec_class.mw = mw
    spec_class.n_bins = 200
    return spec_class.get_data(poisson = False)

# %%
# plot_spectrum(xe_galact, label = 'un-smeared', linestyle = '--')
fig,ax=plt.subplots(figsize = (8,6))
dddm.plot_spectrum(get_det_spec('Xe'), 'red', label = 'Xe det. resolution', plot_error = False)
dddm.plot_spectrum(get_det_spec('Ge'), 'green', label = 'Ge det. resolution', plot_error = False)
dddm.plot_spectrum(get_det_spec('Ar'), 'orange', label = 'Ar det. resolution', plot_error = False)
plt.yscale("log")
plt.ylim(1e-7,1e2)
plt.xlabel("Recoil energy [keV]")
plt.ylabel("Rate [events per (keV ton year)]")
plt.legend()

# %% [markdown]
# # Likelihood profiling

# %%
dddm.plt_ll_sigma_spec()
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 62.16it/s]
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/plot_basics.py:104: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   plt.plot(var, plr, linestyle='steps-mid')

# %%
dddm.plt_ll_sigma_det()
# Out:
# 100%|██████████| 30/30 [00:03<00:00,  8.99it/s]

# %%
dddm.plt_ll_mass_spec()
plt.ylim(-1000,0)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 79.98it/s]
# (-1000, 0)

# %%
dddm.plt_ll_mass_det()
plt.ylim(-1000,0)
# Out:
# 100%|██████████| 100/100 [00:07<00:00, 12.93it/s]
# (-1000, 0)

# %% [markdown]
# # Nested sampling

# %%
fit_class = dddm.NestleStatModel('Xe')
fit_class.tol = 0.8
fit_class.nlive = 2000
print(f"Fitting for parameters:\n{fit_class.fit_parameters}")
# Out:
# StatModel::	initialized for Xe detector. See print(stat_model) for default settings
# Fitting for parameters:
# ['log_mass', 'log_cross_section']

# %%
fit_class.run_nestle()
fit_class.get_summary()
# Out:
# run_nestle::	start_fit for 2 parameters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-867d91fe0b96> in <module>
# ----> 1 fit_class.run_nestle()
#       2 fit_class.get_summary()
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/nestle.py in run_nestle(self)
#     110                                         method=method,
#     111                                         npoints=self.nlive,
# --> 112                                         dlogz=tol)
#     113             end = datetime.datetime.now()
#     114             dt = end - start
#
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/nestle.py in sample(loglikelihood, prior_transform, ndim, npoints, method, update_interval, npdim, maxiter, maxcall, dlogz, decline_factor, rstate, callback, **options)
#     863     for i in range(npoints):
#     864         active_v[i, :] = prior_transform(active_u[i, :])
# --> 865         active_logl[i] = loglikelihood(active_v[i, :])
#     866
#     867     sampler = _SAMPLERS[method](loglikelihood, prior_transform, active_u,
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/nestle.py in _log_probability_nestle(self, theta)
#      90     def _log_probability_nestle(self, theta):
#      91         ndim = len(theta)
# ---> 92         return self.log_probability_nestle(theta, self.known_parameters[:ndim])
#      93
#      94     def _log_prior_transform_nestle(self, theta):
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/nestle.py in log_probability_nestle(self, parameter_vals, parameter_names)
#      62         :return:
#      63         """
# ---> 64         evaluated_rate = self.eval_spectrum(parameter_vals, parameter_names)[
#      65             'counts']
#      66
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/statistics.py in eval_spectrum(self, values, parameter_names)
#     259                 self.config['det_params'])
#     260             spectrum.n_bins = self.config['n_energy_bins']
# --> 261             return spectrum.get_data(poisson=False)
#     262         elif len(parameter_names) == 5 or len(parameter_names) == 6:
#     263             if not parameter_names == default_order[:len(parameter_names)]:
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/detector.py in get_data(self, poisson)
#     157             result['counts'] = self.get_poisson_events()
#     158         else:
# --> 159             result['counts'] = self.get_events()
#     160         bins = get_bins(self.E_min, self.E_max, self.n_bins_result)
#     161         result['bin_centers'] = np.mean(bins, axis=1)
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/detector.py in get_events(self)
#     139         :return: Events (binned)
#     140         """
# --> 141         return self.compute_detected_spectrum()
#     142
#     143     def get_poisson_events(self):
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/detector.py in compute_detected_spectrum(self)
#     124         self.n_bins_result = self.n_bins
#     125         self.n_bins = self.n_bins * self.rebin_factor
# --> 126         rates = self.spectrum_simple([self.mw, self.sigma_nucleon])
#     127         energies = self.get_bin_centers()
#     128         rates = self.above_threshold(rates, energies)
#
# /data/xenon/joranang/software/DD_DM_targets/DirectDmTargets/halo.py in spectrum_simple(self, benchmark)
#      86                                 benchmark["sigma_nucleon"],
#      87                                 halo_model=self.dm_model,
# ---> 88                                 **kwargs
#      89                                 )
#      90         return rate
#
# /data/xenon/joranang/software/wimprates/wimprates/summary.py in rate_wimp_std(es, mw, sigma_nucleon, m_med, t, halo_model, **kwargs)
#      77                       sigma_nucleon=sigma_nucleon * nu.cm**2,
#      78                       m_med=m_med * nu.GeV/nu.c0**2,
# ---> 79                       t=t, halo_model=halo_model, **kwargs)
#      80             * (nu.keV * (1000 * nu.kg) * nu.year))
#
# /data/xenon/joranang/software/wimprates/wimprates/summary.py in rate_wimp(es, mw, sigma_nucleon, interaction, detection_mechanism, m_med, t, halo_model, **kwargs)
#      53     return dmechs[detection_mechanism](
#      54         es, mw=mw, sigma_nucleon=sigma_nucleon, interaction=interaction,
# ---> 55         m_med=m_med, halo_model=halo_model, t=t, **kwargs)
#      56
#      57
#
# <boltons.funcutils.FunctionBuilder-1> in rate_elastic(erec, mw, sigma_nucleon, interaction, m_med, t, material, halo_model, **kwargs)
#
# /data/xenon/joranang/software/wimprates/wimprates/utils.py in newf(xs, *args, **kwargs)
#      58             return np.array(
#      59                 [f(x, *args, **kwargs)
# ---> 60                  for x in itr(xs)])
#      61         return f(xs, *args, **kwargs)
#      62     return newf
#
# /data/xenon/joranang/software/wimprates/wimprates/utils.py in <listcomp>(.0)
#      58             return np.array(
#      59                 [f(x, *args, **kwargs)
# ---> 60                  for x in itr(xs)])
#      61         return f(xs, *args, **kwargs)
#      62     return newf
#
# /data/xenon/joranang/software/wimprates/wimprates/elastic_nr.py in rate_elastic(erec, mw, sigma_nucleon, interaction, m_med, t, material, halo_model, **kwargs)
#     225         integrand,
#     226         v_min, wr.v_max(t, halo_model.v_esc),
# --> 227         **kwargs)[0]
#
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /data/xenon/joranang/anaconda/envs/dddm/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /data/xenon/joranang/software/wimprates/wimprates/elastic_nr.py in integrand(v)
#     220         return (sigma_erec(erec, v, mw, sigma_nucleon,
#     221                            interaction, m_med, material=material) * v
# --> 222                 * halo_model.velocity_dist(v, t))
#     223
#     224     return halo_model.rho_dm / mw * (1 / mn(material)) * quad(
#
# /data/xenon/joranang/software/wimprates/wimprates/elastic_nr.py in sigma_erec(erec, v, mw, sigma_nucleon, interaction, m_med, material)
#     134         result = (sigma_nucleus
#     135                   / e_max(mw, v, mn(material))
# --> 136                   * helm_form_factor_squared(erec,
#     137                                              anucl=ATOMIC_WEIGHT[material]))
#     138
#
# /data/xenon/joranang/software/wimprates/wimprates/elastic_nr.py in mn(material)
#      21 def mn(material='Xe'):
#      22     """Mass of nucleus (not nucleon!)"""
# ---> 23     return ATOMIC_WEIGHT[material] * nu.amu
#      24
#      25
#
# KeyboardInterrupt:

# %%
fit_class.show_corner()

# %%
fit_unconstrained = dddm.NestleStatModel('Xe')
fit_unconstrained.tol = 0.8
fit_unconstrained.nlive = 2000
fit_unconstrained.set_fit_parameters(fit_unconstrained.known_parameters)
print(f"Fitting for parameters:\n{fit_unconstrained.fit_parameters}")

# %%
fit_unconstrained.run_nestle()
fit_unconstrained.get_summary()

# %%
fit_unconstrained.show_corner()
